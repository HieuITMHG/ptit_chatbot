# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AIzaSyBampfSi5j10MI-ZWreQ0zIE8qJTM6Vpj4"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
from langchain.agents import create_agent


# If desired, specify custom instructions
prompt = (
    "trả lời tất cẩ câu hỏi bằng tiếng việt "
)
agent = create_agent(model, system_prompt=prompt)

# %%
query = (
    "viết bài văn nghị luận chủ đề tự do"
)

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# viết bài văn nghị luận chủ đề tự do
# ================================== Ai Message ==================================
#
# Chủ đề tự do là một trong những chủ đề muôn thuở, luôn thôi thúc con người suy tư, tranh luận và đấu tranh để giành lấy. Tự do không chỉ là một khái niệm trừu tượng mà còn là một giá trị sống cốt lõi, là động lực thúc đẩy sự phát triển của cá nhân và xã hội.
#
# Trước hết, cần hiểu rõ tự do là gì. Tự do có thể hiểu là trạng thái không bị ràng buộc, không bị ép buộc, có quyền tự quyết định hành động, suy nghĩ và lựa chọn của bản thân. Tuy nhiên, tự do không phải là sự buông thả vô giới hạn. Tự do đích thực luôn đi kèm với trách nhiệm. Tự do của mỗi người phải không xâm phạm đến tự do và quyền lợi hợp pháp của người khác. Nó cần được đặt trong khuôn khổ pháp luật, đạo đức và các quy tắc xã hội để đảm bảo sự hài hòa và trật tự chung.
#
# Tự do mang nhiều khía cạnh. Có tự do cá nhân, bao gồm quyền tự do tư tưởng, tự do ngôn luận, tự do tín ngưỡng, tự do đi lại, tự do lập hội... Đây là những quyền cơ bản mà mỗi con người đều xứng đáng được hưởng. Khi con người được tự do thể hiện bản thân, họ có thể phát huy tối đa tiềm năng, sáng tạo và đóng góp cho xã hội. Ngược lại, một xã hội kìm hãm tự do cá nhân sẽ dễ rơi vào trì trệ, thiếu sức sống.
#
# Bên cạnh đó, còn có tự do chính trị, tự do kinh tế, tự do văn hóa... Tự do chính trị cho phép công dân tham gia vào đời sống chính trị, có quyền bầu cử, ứng cử và giám sát hoạt động của bộ máy nhà nước. Tự do kinh tế tạo điều kiện cho các hoạt động sản xuất, kinh doanh phát triển, mang lại sự thịnh vượng cho đất nước. Tự do văn hóa khuyến khích sự đa dạng, sáng tạo trong lĩnh vực nghệ thuật, văn học, khoa học.
#
# Lịch sử đã chứng minh vai trò to lớn của tự do trong việc thúc đẩy tiến bộ xã hội. Những cuộc cách mạng, những phong trào giải phóng dân tộc, những bước đột phá trong khoa học kỹ thuật đều ít nhiều gắn liền với khát vọng và cuộc đấu tranh cho tự do. Nơi nào tự do được tôn trọng và bảo vệ, nơi đó con người được sống một cuộc đời ý nghĩa, được phát triển toàn diện và xã hội ngày càng văn minh, tiến bộ.
#
# Tuy nhiên, hành trình giành lấy và bảo vệ tự do không hề dễ dàng. Trên thế giới, vẫn còn nhiều nơi con người phải đối mặt với sự áp bức, bất công, thiếu vắng các quyền tự do cơ bản. Ngay cả trong những xã hội được xem là tự do, vẫn luôn tồn tại những thách thức, những nguy cơ xâm phạm đến tự do của con người, đòi hỏi sự cảnh giác và nỗ lực không ngừng để gìn giữ.
#
# Đối với mỗi cá nhân, việc nhận thức và thực hành tự do là vô cùng quan trọng. Chúng ta cần hiểu rõ quyền và trách nhiệm của mình, biết cách sử dụng tự do một cách khôn ngoan, có ích. Học tập, trau dồi kiến thức, rèn luyện đạo đức, tham gia vào các hoạt động cộng đồng là những cách để mỗi người tự giải phóng mình khỏi những giới hạn, những định kiến, để sống một cuộc đời tự do và có ý nghĩa.
#
# Tóm lại, tự do là một giá trị thiêng liêng, là nền tảng cho sự phát triển của cá nhân và xã hội. Nó không phải là thứ có sẵn mà là kết quả của sự đấu tranh, nỗ lực và ý thức trách nhiệm. Chúng ta hãy trân trọng, bảo vệ và không ngừng vun đắp cho tự do, để mỗi con người có thể sống một cuộc đời trọn vẹn, hạnh phúc và đóng góp hết mình cho sự phát triển chung của nhân loại.
